# %% [markdown]
# #### Collections
# #### Strings

# %%
# Strings are immutable and combinations of characters 
name = 'Raghav'

print(name.count('a'))
# Out:
# 2

# %%
print(name.replace('a', 'A'))
# Out:
# RAghAv

# %%
print(name.find('a')) # Finds the index of the given character
# Out:
# 1

# %%
print(name.upper())
# Out:
# RAGHAV

# %%
print(name.lower())
# Out:
# raghav

# %%
name.split("a")
# Out:
# ['R', 'gh', 'v']

# %%
boarding_call="Good Evening, this is the final call to AL passengers for the flight AL 466 which is planned to take off at 8.40A.M."
if(boarding_call.startswith("Good Evening")):
    print(boarding_call.replace("Good Evening","Good Morning"))
if(boarding_call.find("AL"))>=0:
    print("Welcome to Air Lines.")
if(boarding_call.endswith("A.M.")):
    print("Passengers are requested to have their breakfast.")
a=boarding_call.split(" ")
for i in a:
    if(i.isdigit()):
        print("Flight Number is specified to the passengers.")
print("Total number of times flight service name is specified in the boarding call:",boarding_call.count("AL"))
message="Thank you all..Have a nice journey!"
print(message.upper())
print(message.lower())
# Out:
# Good Morning, this is the final call to AL passengers for the flight AL 466 which is planned to take off at 8.40A.M.
# Welcome to Air Lines.
# Passengers are requested to have their breakfast.
# Flight Number is specified to the passengers.
# Total number of times flight service name is specified in the boarding call: 2
# THANK YOU ALL..HAVE A NICE JOURNEY!
# thank you all..have a nice journey!

# %%
name = "Stark"
print(f"He said his name is {name}")
# Out:
# He said his name is Stark

# %%
width = 10
height = 20
print(f"The perimeter of the given rectangle is {(2*width) + (2*height)} and the area is {width * height}.")
# Out:
# The perimeter of the given rectangle is 60 and the area is 200.

# %%
print(r"C\\Users\\Stark\\Documents\\Books\\Python")
# Out:
# C\\Users\\Stark\\Documents\\Books\\Python

# %%
pancard_number="AABGT6715H"
print("Length of the PAN card number:", len(pancard_number))

name1 = "PAN"
name2 = "card"
name = name1 + name2
print(name)

print("Interating the string using range()")
for index in range(0, len(pancard_number)):
    print(pancard_number[index])
# Out:
# Length of the PAN card number: 10
# PANcard
# Interating the string using range()
# A
# A
# B
# G
# T
# 6
# 7
# 1
# 5
# H

# %%
"""
Write a Python program to generate the ticket numbers for specified number of passengers traveling in a flight as per the details mentioned below:
The ticket number should be generated as airline:src:dest:number where,

Consider AL1 as the value for airline

src and dest should be the first three characters of the source and destination cities.

number should be auto-generated starting from 101

The program should return the list of ticket numbers of last five passengers.
Note: If passenger count is less than 5, then return the list of all generated ticket numbers."""



def ticket_num_generation(num_passengers, source, destination):
    tickets = []
    airline = 'AL1'

    src = source[:3]
    dest = destination[:3]

    for i in range(num_passengers):
        number = 101 + 1
        ticket = airline+src+dest+str(number)
        tickets.append(ticket)

    if num_passengers >= 5:
        print(tickets[:-5])
    else:
        print(tickets[:5])


ticket_num_generation(3, "Bangalore", "London")
ticket_num_generation(8, "Hyderabad", "Chicago")
# Out:
# ['AL1BanLon102', 'AL1BanLon102', 'AL1BanLon102']
# ['AL1HydChi102', 'AL1HydChi102', 'AL1HydChi102']

# %%
list_of_airlines=["AL1","AL2","AL3"]
print("Iterating the list using range()")
for index in range(0,len(list_of_airlines)):
    print(list_of_airlines[index])
print("Iterating the list using keyword in")
for airline in list_of_airlines:
    print(airline)
# Out:
# Iterating the list using range()
# AL1
# AL2
# AL3
# Iterating the list using keyword in
# AL1
# AL2
# AL3

# %%
list_of_airlines=["AL1","AL2","AL3"]
airline="AL3"
if airline in list_of_airlines:
    print("Airline found")
else:
    print("Airline not found")
# Out:
# Airline found

# %%
#Given a list of integer values, write a Python program to check whether the list contains the same number in adjacent positions. Display the count of such adjacent occurrences.

def adj_pos(list):
    total_pos = 0
    for i in range(len(list)):
        current = list[i-1]
        next = list[i]
        if current == next:
            total_pos += 1
    return total_pos

list = [1,2,2,3,4,4,4,10]
print(adj_pos(list))
# Out:
# 3

# %%
list = [1,1,5,100,-20,-20,6,0,0]
print(len(list))
# Out:
# 9

# %%
items = {'Carrot', 'chilly', 'Pepper'}
print(items)
# Out:
# {'Carrot', 'chilly', 'Pepper'}

# %%
Items = {"Carrot", "Chilly", "Pepper", "Orange"}
Items.add("orange")
print(Items)
# Out:
# {'Chilly', 'orange', 'Orange', 'Carrot', 'Pepper'}

# %%
items = {"carrot", "chilly", "pepper"}
items.discard('chilly')
print(items)
# Out:
# {'carrot', 'pepper'}

# %%
Items = {"Carrot", "Chilly", "Pepper"}
Items.pop()
# Out:
# 'Chilly'

# %%
items1 = {'carrot', 'chilly', 'pepper'}
items2 = {"carrot", "chilly", "pepper", "orange"}
items3 = items1.union(items2)
print(items3)
# Out:
# {'chilly', 'orange', 'carrot', 'pepper'}

# %%
items1 = {'orange', 'chilly', 'pepper'}
items2 = {'carrot', 'chilly', 'pepper', 'arange'}
items3 = items1.difference(items2)
print(items3)
# Out:
# {'orange'}

# %%
Items1 = {"Carrot", "Chilly", "Pepper"}
Items2 = {"Carrot", "Chilly", "Pepper", "orange"}
Items3 = Items1.symmetric_difference(Items2)
print(Items3)
# Out:
# {'orange'}

# %%
crew_details = {"Pilot":"Kumar",
"Co-pilot":"Raghav",
"Head-Strewardess":"Malini",
"Stewardess":"Mala" }

for key, value in crew_details.items():
    print(f"{key} : {value}")
# Out:
# Pilot : Kumar
# Co-pilot : Raghav
# Head-Strewardess : Malini
# Stewardess : Mala

# %%
crew_details={
    "Pilot" : "Kumar",
    "Co-Pilot" : "Raghav",
    "Head-Strewardness" : "Malini",
    "Stewardness":"Mala"
}

print("Before Updates")
print("Co-Pilot", crew_details)
crew_details.update({
    "Flight-Attendant" : "Jane",
    "Co-Pilot" :"Henry"
})

print("\nAfter Update:")
print(crew_details)
# Out:
# Before Updates
# Co-Pilot {'Pilot': 'Kumar', 'Co-Pilot': 'Raghav', 'Head-Strewardness': 'Malini', 'Stewardness': 'Mala'}
#
# After Update:
# {'Pilot': 'Kumar', 'Co-Pilot': 'Henry', 'Head-Strewardness': 'Malini', 'Stewardness': 'Mala', 'Flight-Attendant': 'Jane'}

# %%
my_list=[0]*5
my_list
# Out:
# [0, 0, 0, 0, 0]
